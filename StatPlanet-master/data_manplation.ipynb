# %%
import pandas as pd
import numpy as np

# %%
excel_file=pd.read_excel('spreadsheet.xlsx')
excel_file.shape
# Out:
# (108, 249)

# %%
excel_file=excel_file.iloc[:,11:]
excel_file.columns=excel_file.iloc[0]
excel_file=excel_file.iloc[1:,:]
excel_file.shape
# Out:
# (107, 238)

# %%
json_file=pd.read_json('cdnMetrics.json',orient='records')
json_file
# Out:
#                        CN    CR    GB    ID    HK    IT    BE    LV    BA  \
# ThirdParty           19.4  38.6  50.2  51.4  54.4  55.6  56.0  56.8  56.8
# critical_dependency  11.2   5.2   7.4   5.6  10.8   8.0  16.4  19.2  13.4
# thirdndPrivate        0.0  25.0  28.0  38.6   3.6  34.2   3.8   1.2   0.8
# redundant             8.2  38.2  48.6  56.8  44.0  53.2  39.8  38.4  44.2
# multipleThirdParty    5.0  20.4  27.8  27.4  36.4  31.2  26.8  29.8  33.2
#
#                        DK    IN    AL    MX    TR    FR    KR    JP    IL  \
# ThirdParty           57.4  57.4  57.8  60.8  60.8  61.0  61.0  63.6  64.6
# critical_dependency   9.0   8.6  10.8  10.6  14.2  22.0  19.4  11.8  12.8
# thirdndPrivate       26.0  36.2   1.4   3.0   1.4   1.6   2.2   2.8  43.0
# redundant            54.2  57.8  48.0  51.0  47.0  39.4  42.6  52.6  56.6
# multipleThirdParty   36.8  34.6  33.8  44.8  36.2  30.8  34.6  47.2  36.8
#
# ...

# %%
country_code=pd.read_csv('country_codes.csv')
country_code
# Out:
#                   Name Code
# 0          Afghanistan   AF
# 1       Ã…land Islands   AX
# 2              Albania   AL
# 3              Algeria   DZ
# 4       American Samoa   AS
# ..                 ...  ...
# 244  Wallis and Futuna   WF
# 245     Western Sahara   EH
# 246              Yemen   YE
# 247             Zambia   ZM
# 248           Zimbabwe   ZW
#
# [249 rows x 2 columns]

# %%
# country_code[country_code['Code']=='AF'].iat[0,0]
# # if 'AF' in country_code['Code'].values:
# #     print("yes")
# json_file.columns=json_file.columns.str.replace('CN','China')
# json_file

# %%
for (name,data) in json_file.iteritems():
    if name in country_code['Code'].values:
        json_file.columns=json_file.columns.str.replace(name,country_code[country_code['Code']==name].iat[0,0])
    else:
        print(name)

# %%
print(json_file.shape)
json_file
# Out:
# (5, 48)
#                      China  Costa Rica  United Kingdom  Indonesia  Hong Kong  \
# ThirdParty            19.4        38.6            50.2       51.4       54.4
# critical_dependency   11.2         5.2             7.4        5.6       10.8
# thirdndPrivate         0.0        25.0            28.0       38.6        3.6
# redundant              8.2        38.2            48.6       56.8       44.0
# multipleThirdParty     5.0        20.4            27.8       27.4       36.4
#
#                      Italy  Belgium  Latvia  Bosnia and Herzegovina  Denmark  \
# ThirdParty            55.6     56.0    56.8                    56.8     57.4
# critical_dependency    8.0     16.4    19.2                    13.4      9.0
# thirdndPrivate        34.2      3.8     1.2                     0.8     26.0
# redundant             53.2     39.8    38.4                    44.2     54.2
# multipleThirdParty    31.2     26.8    29.8                    33.2     36.8
#
# ...

# %%
new_col=excel_file.iloc[0]
# excel_file=excel_file[1:]
# excel_file.columns=new_col
# excel_file
new_excel=pd.DataFrame(columns=new_col)
new_excel
# Out:
# Empty DataFrame
# Columns: [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, ...]
# Index: []

# %%
# final_excel= new_excel.merge(json_file)
json_file=json_file.reset_index(drop=True)
json_file
# final_excel=pd.concat([excel_file,json_file],axis=0)
# final_excel
# Out:
#    China  Costa Rica  United Kingdom  Indonesia  Hong Kong  Italy  Belgium  \
# 0   19.4        38.6            50.2       51.4       54.4   55.6     56.0
# 1   11.2         5.2             7.4        5.6       10.8    8.0     16.4
# 2    0.0        25.0            28.0       38.6        3.6   34.2      3.8
# 3    8.2        38.2            48.6       56.8       44.0   53.2     39.8
# 4    5.0        20.4            27.8       27.4       36.4   31.2     26.8
#
#    Latvia  Bosnia and Herzegovina  Denmark  India  Albania  Mexico  Turkey  \
# 0    56.8                    56.8     57.4   57.4     57.8    60.8    60.8
# 1    19.2                    13.4      9.0    8.6     10.8    10.6    14.2
# 2     1.2                     0.8     26.0   36.2      1.4     3.0     1.4
# 3    38.4                    44.2     54.2   57.8     48.0    51.0    47.0
# 4    29.8                    33.2     36.8   34.6     33.8    44.8    36.2
#
# ...

# %%
# final_excel=pd.merge(excel_file,json_file)
# final_excel=excel_file.merge(json_file,how='left')
# final_excel
#json_file.columns = json_file.columns.str.replace('China', 'Afganistan')
check_json_file_col=json_file.columns

# %%
all_countries=excel_file.columns
current_countries=json_file.columns
for country in all_countries:
    if country not in current_countries:
        json_file[country]=np.nan

# %%
# del json_file['Channel Islands']

# %%
# json_file=json_file.sort_index(axis=1)
# json_file
pd.set_option('display.max_columns', None)
json_file
# Out:
#    China  Costa Rica  United Kingdom  Indonesia  Hong Kong  Italy  Belgium  \
# 0   19.4        38.6            50.2       51.4       54.4   55.6     56.0
# 1   11.2         5.2             7.4        5.6       10.8    8.0     16.4
# 2    0.0        25.0            28.0       38.6        3.6   34.2      3.8
# 3    8.2        38.2            48.6       56.8       44.0   53.2     39.8
# 4    5.0        20.4            27.8       27.4       36.4   31.2     26.8
#
#    Latvia  Bosnia and Herzegovina  Denmark  India  Albania  Mexico  Turkey  \
# 0    56.8                    56.8     57.4   57.4     57.8    60.8    60.8
# 1    19.2                    13.4      9.0    8.6     10.8    10.6    14.2
# 2     1.2                     0.8     26.0   36.2      1.4     3.0     1.4
# 3    38.4                    44.2     54.2   57.8     48.0    51.0    47.0
# 4    29.8                    33.2     36.8   34.6     33.8    44.8    36.2
#
# ...

# %%
# del json_file["People's Republic of Korea"]
# json_file=json_file.sort_index(axis=1)
# json_file
# json_file

# %%
json_file["Rep. of Korea"]=json_file['Korea, Republic of']
json_file["Rep. of Moldova"]=json_file['Moldova, Republic of']
json_file["Taiwan"]=json_file['Taiwan, Province of China']
del json_file['Korea, Republic of']
del json_file['Moldova, Republic of']
del json_file['Taiwan, Province of China']

# %%
json_file.shape
# Out:
# (5, 237)

# %%
excel_file.shape
excel_file.shape
# Out:
# (107, 238)

# %%
# excel_list=excel_file.columns
# json_list=json_file.columns
# for i in range(len(json_list)):
#     if (excel_list[i]!=json_list[i]):
#         print(excel_list[i])

# %%
len(check_json_file_col)
# Out:
# 48

# %%
for cn in json_file.columns:
    if cn not in all_countries:
        print(cn)

# %%
for cn in all_countries:
    if cn not in json_file.columns:
        print(cn)

# %%
len(all_countries.unique())
# Out:
# 237

# %%
len(all_countries)
# Out:
# 238

# %%
import collections
print([item for item, count in collections.Counter(all_countries).items() if count > 1])
# Out:
# ['Hong Kong']

# %%
del excel_file['Hong Kong']
excel_file.shape
new_excel=pd.DataFrame(columns=excel_file.columns)

# %%
excel_file['Hong Kong']=np.nan
excel_file.shape
# Out:
# (107, 237)

# %%
new_excel=pd.DataFrame(columns=excel_file.columns)
final_file=pd.concat([new_excel,json_file])

# %%
final_file
# Out:
#    Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# 0          NaN     57.8      NaN      NaN     NaN       NaN
# 1          NaN     10.8      NaN      NaN     NaN       NaN
# 2          NaN      1.4      NaN      NaN     NaN       NaN
# 3          NaN     48.0      NaN      NaN     NaN       NaN
# 4          NaN     33.8      NaN      NaN     NaN       NaN
#
#    Antigua and Barbuda  Argentina  Armenia  Aruba  Australia  Austria  \
# 0                  NaN       67.8      NaN    NaN       75.6      NaN
# 1                  NaN       11.2      NaN    NaN       13.6      NaN
# 2                  NaN        4.2      NaN    NaN        2.2      NaN
# 3                  NaN       57.2      NaN    NaN       62.8      NaN
# 4                  NaN       49.4      NaN    NaN       54.8      NaN
#
#    Azerbaijan  Bahamas  Bahrain  Bangladesh  Barbados  Belarus  Belgium  \
# 0         NaN      NaN      NaN         NaN       NaN      NaN     56.0
# ...

# %%
final_file.to_excel('cdn_data.xlsx')
